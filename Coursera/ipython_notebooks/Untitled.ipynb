# %%
print "hw"
# Out:
#   File "<ipython-input-1-2212232fbd36>", line 1
#     print "hw"
#              ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("hw")?

# %%
print("j")
# Out:
# j

# %% [markdown]
# $$ \log(2) $$

# %% [markdown]
# $ \pow(2, 3)$

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
y = [1,2,4,3,2,4,1,5,3,0,6]
plot(y)
